# %%
#Run the following code to print multiple outputs from a cell
get_ipython().ast_node_interactivity = 'all'

# %% [markdown]
# ## Connections 2: Using Generative AI to Create a Graph with plotnine

# %% [markdown]
# This assignment introduces you to using generative AI tools (such as Microsoft Copilot) to assist with Python coding. You will use AI to help you create a graph using the plotnine package—even though we haven’t yet covered this package in class. The goal is to explore how AI can support your coding efforts, while also recognizing that it may take multiple iterations to get the code right.

# %% [markdown]
# For this assignment, you'll need to use Microsoft Copilot. If you've never used it before, you can follow these steps to get started:
#
# * Go to: m365.cloud.microsoft/chat
# * Click Sign in.
# * Enter your username@bc.edu
# * When prompted, select Work or school account.
# * On the BC Single Sign On (SSO) login page, enter your BC Credentials (the username and password you use for Agora Portal) and complete BC 2-Step Verification.
# * Once logged in, you will see a shield in the upper right (next to the New chat button), indicating that your information is protected.

# %% [markdown]
# ### Part 1. Using AI to Generate Code
#
# Use Microsoft Copilot to help you create a graph that matches the reference image provided below:
#
# ![Connections2Graph.png](attachment:d8f64499-cb6c-4d41-844d-2d4c6bed83d0.png)
#
# Here's information you will need to create this graph:
#
# * **Do *not* paste the image or copy/paste this assignment prompt into Copilot. Instead, describe the graph in your own words and use the Python code Copilot provides to create the graph below.**
# * You should use the creditCardDefaultReduced.csv dataset and include the variables `Payment` and `Card`.
# * The graph ***must*** be created using the plotnine package. (Note: Copilot may suggest installing the package, but it is already installed in Jupyter Hub.)
# * You do not need to replicate the watermark, but you *should* try to approximate the colors (gold and maroon) and match the title and y-axis label.
# * **IMPORTANT: Do not spend more than 30 minutes on this task. The goal is exposure, not perfection.**

# %% [markdown]
# 1. **In the code cell below, copy/paste the initial code that Microsoft Copilot provided (regardless of whether it works).**

# %%
# copy/paste the initial code below

# %% [markdown]
# 2. **In the code cell below, copy/paste your final code to reproduce the graph.**

# %%
# copy/paste your final code below

# %% [markdown]
# **For full credit, you will need to copy/paste your entire conversation with Microsoft Copilot into a Word document and submit that to the Canvas assignment, along with an html version of this notebook file.** This helps confirm that you interacted with Copilot and did not simply paste the image of the graph into the chat.

# %% [markdown]
# ### Part 2. Reflection
#
# 3. **Write 3–5 sentences to answer the following question: What did you learn about using generative AI for coding? What surprised you, and what challenges did you encounter?**

# %% [markdown]
# [double-click here to type your answer]
